# %%
import pandas as pd
import  numpy  as  np

# %%
student = pd.read_csv("Student.csv")
student
# Out:
#    RollNo      Name depid
# 0     101      abhi  D001
# 1     102       raj  D001
# 2     103     kumar  D002
# 3     104  abhiskek  D001
# 4     105   fardeen  D003
# 5     106   yougesh  D001
# 6     107    ganesh  D002
# 7     108    goyrav  D003
# 8     109    rajesh  D001
# 9     110      raju  D003

# %%
department = pd.read_csv("department .csv")
department
# Out:
#   depid dname       HodName
# 0  D001   CSE       LUV Sir
# 1  D002   ITE    Vishal Sir
# 2  D003   MCA  Pradhasn Sir

# %%
merged_data = pd.merge(student, department,  on ='depid')
merged_data
# Out:
#    RollNo      Name depid dname       HodName
# 0     101      abhi  D001   CSE       LUV Sir
# 1     102       raj  D001   CSE       LUV Sir
# 2     103     kumar  D002   ITE    Vishal Sir
# 3     104  abhiskek  D001   CSE       LUV Sir
# 4     105   fardeen  D003   MCA  Pradhasn Sir
# 5     106   yougesh  D001   CSE       LUV Sir
# 6     107    ganesh  D002   ITE    Vishal Sir
# 7     108    goyrav  D003   MCA  Pradhasn Sir
# 8     109    rajesh  D001   CSE       LUV Sir
# 9     110      raju  D003   MCA  Pradhasn Sir

# %%
data =merged_data.loc[(merged_data['RollNo'] ==  101)  | (merged_data['RollNo'] ==  102)] 
data
# Out:
#    RollNo  Name depid dname  HodName
# 0     101  abhi  D001   CSE  LUV Sir
# 1     102   raj  D001   CSE  LUV Sir

# %% [markdown]
# ## print the no of student department wisem

# %%
result = merged_data.groupby('dname')['RollNo'].count()
result
# Out:
# dname
# CSE    5
# ITE    2
# MCA    3
# Name: RollNo, dtype: int64

# %%
merged_new = pd.merge(student, department,  left_on ='depid', right_on='department')
merged_new
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 merged_new = pd.merge(student, department,  left_on ='depid', right_on='department')
#       2 merged_new
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\reshape\merge.py:385, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     371     return _cross_merge(
#     372         left_df,
#     373         right_df,
#    (...)    382         validate=validate,
#     383     )
#     384 else:
# --> 385     op = _MergeOperation(
#     386         left_df,
#     387         right_df,
#     388         how=how,
#     389         on=on,
#     390         left_on=left_on,
#     391         right_on=right_on,
#     392         left_index=left_index,
#     393         right_index=right_index,
# ...

# %%
student_df = pd.read_csv("Student.csv")
student_df
# Out:
#    RollNo      Name depid
# 0     101      abhi  D001
# 1     102       raj  D001
# 2     103     kumar  D002
# 3     104  abhiskek  D001
# 4     105   fardeen  D003
# 5     106   yougesh  D001
# 6     107    ganesh  D002
# 7     108    goyrav  D003
# 8     109    rajesh  D001
# 9     110      raju  D003

# %%
department_df = pd.read_csv("Student.csv")
department_df
# Out:
#    RollNo      Name depid
# 0     101      abhi  D001
# 1     102       raj  D001
# 2     103     kumar  D002
# 3     104  abhiskek  D001
# 4     105   fardeen  D003
# 5     106   yougesh  D001
# 6     107    ganesh  D002
# 7     108    goyrav  D003
# 8     109    rajesh  D001
# 9     110      raju  D003

# %%
merge_df = pd.merge(student_df,department_df,left_on ='department',right_on='depid')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 merge_df = pd.merge(student_df,department_df,left_on ='department',right_on='depid')
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\reshape\merge.py:385, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     371     return _cross_merge(
#     372         left_df,
#     373         right_df,
#    (...)    382         validate=validate,
#     383     )
#     384 else:
# --> 385     op = _MergeOperation(
#     386         left_df,
#     387         right_df,
#     388         how=how,
#     389         on=on,
#     390         left_on=left_on,
#     391         right_on=right_on,
#     392         left_index=left_index,
#     393         right_index=right_index,
#     394         sort=sort,
# ...
