# %%
import pandas as pd
import numpy as np

# %%
## pandas

# %%
df = pd.DataFrame()
columns:[]
Indx:[]

# %%
print(type(df))
# Out:
# <class 'pandas.DataFrame'>

# %%
## data frame from list

# %%
data = ['ram','shyam', 'Mohan', 'Sohan']
df = pd.DataFrame(data)
print(df)
# Out:
#        0
# 0    ram
# 1  shyam
# 2  Mohan
# 3  Sohan

# %%
df[0]
# Out:
# 0      ram
# 1    shyam
# 2    Mohan
# 3    Sohan
# Name: 0, dtype: str

# %%
## Making Data Frame From List to List 1

# %%
data = [['Ram', 23, 89000], ['Shyam', 22, 23000], ['Mohan', 24, 7800]]
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#        0   1      2
# 0    Ram  23  89000
# 1  Shyam  22  23000
# 2  Mohan  24   7800

# %%
df[1]
# Out:
# 0    23
# 1    22
# 2    24
# Name: 1, dtype: int64

# %%
df.rename(columns={0: 'Name', 1: 'Age', 2: 'Salary'}, inplace = True)

# %%
df['Name']
# Out:
# 0      Ram
# 1    Shyam
# 2    Mohan
# Name: Name, dtype: str

# %%
df
# Out:
#     Name  Age  Salary
# 0    Ram   23   89000
# 1  Shyam   22   23000
# 2  Mohan   24    7800

# %%
## To Print the content of row 1

# %%
df.loc[0]
# Out:
# Name        Ram
# Age          23
# Salary    89000
# Name: 0, dtype: object

# %%
df.iloc[0]
# Out:
# Name        Ram
# Age          23
# Salary    89000
# Name: 0, dtype: object

# %%
df.loc[[0, 1]]
# Out:
#     Name  Age  Salary
# 0    Ram   23   89000
# 1  Shyam   22   23000

# %%
df = pd.read_csv("sample.csv")
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv("sample.csv")
#       2 df
#
# NameError: name 'pd' is not defined
