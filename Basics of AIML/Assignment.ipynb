# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Sample1.csv")

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Write a Pandas program to display the dimensions or shape of the World alcohol

# %%
print("Dimensions (Rows, Columns):", df.shape)
# Out:
# Dimensions (Rows, Columns): (100, 5)

# %%
print("Number of Rows:", df.shape[0])
print("Number of Columns:", df.shape[1])
# Out:
# Number of Rows: 100
# Number of Columns: 5

# %%
df.loc[(df['Year'] == 1987) & (df['Year'] == 1989)]
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.loc[(df['Year'] == 1987) & (df['Year'] == 1989)]
#       2 df
#
# NameError: name 'df' is not defined

# %%
df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df.shape
#
# NameError: name 'df' is not defined

# %%
df = pd.read_csv("Sample1.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pd.read_csv("Sample1.csv")
#
# NameError: name 'pd' is not defined
