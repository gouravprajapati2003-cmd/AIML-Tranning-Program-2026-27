# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Placement.csv")

# %%
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'], df['package'])

# %%
plt.scatter(df['cgpa'], df['package'])
plt.xlabel('CGPA')
plt.ylabel('Package(in laks)')
# Out:
# Text(0, 0.5, 'Package(in laks)')

# %%
X = df.iloc[:,0:1]

# %%
X
# Out:
#      cgpa
# 0    6.89
# 1    5.12
# 2    7.82
# 3    7.42
# 4    6.94
# ..    ...
# 195  6.93
# 196  5.89
# 197  7.21
# 198  7.63
# 199  6.22
#
# [200 rows x 1 columns]

# %%
y = df.iloc[:,-1]

# %%
y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .2)

# %%
X_train
# Out:
#      cgpa
# 40   9.38
# 120  5.23
# 9    8.31
# 159  8.71
# 195  6.93
# ..    ...
# 186  7.84
# 158  5.95
# 71   7.47
# 135  6.10
# 168  8.65
#
# [160 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(df['cgpa'], df['package'])
plt.plot(X_train, lr.predict(X_train), color="red")
plt.xlabel('CGPA')
plt.ylabel('Package(in laks)')
# Out:
# Text(0, 0.5, 'Package(in laks)')

# %%
m = lr.coef_
m
# Out:
# array([0.57657509])

# %%
c = lr.intercept_
c
# Out:
# np.float64(-1.0324739109482914)

# %%
result = lr.predict(X_test.iloc[0].values.reshape(1,1))
result
# Out:
# C:\Users\hp\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.38409128])

# %%
import pickle

# %%
pickle.dump(lr, open("Placementpkg.pkl","wb"))

# %%
lr.predict(pd.DataFrame([[5.12]]))
# Out:
# C:\Users\hp\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1.91959055])
